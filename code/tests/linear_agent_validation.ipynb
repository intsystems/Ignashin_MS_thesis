# %%
import os
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
os.chdir(parent_dir)

import numpy as np
import matplotlib.pyplot as plt

from src.skygraph import SkyGraph
from src.skygraph import SkyAgent, LinearSkyAgent
from src.skygraph import SkyModel
from src.skygraph.model import LOGGER

from src.skygraph.agents.utils import test_agents

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Init target model

# %%
# stay_prob of default model in graph._default()
stay_prob = [0.5, 1.0/3, 1.0/3, 0.25, 1.0/3]
target_agent = LinearSkyAgent(5 , beta_cost = 0.01 , beta_capacity = 0.06, stay_prob = stay_prob )

# %% [markdown]
# ## Init our model for training weights
# * weights: beta_cost, best_capacity, stay_prob

# %%
current_agent = LinearSkyAgent(5 , beta_cost = 0.0 , beta_capacity = 0.0, stay_prob = 0.2 )

# %% [markdown]
# ## Visualise current agents
# * target
# * our initialized agent
# * uniform agent

# %%
agents = [
    target_agent, 
    current_agent,
    SkyAgent(5)
]

test_agents(agents)

# %% [markdown]
# ## Sample trajectories and log it
# * training data:
# 1) count people in vertices
# 2) Graph parameters
